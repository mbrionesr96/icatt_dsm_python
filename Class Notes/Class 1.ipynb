# %% [markdown]
# # Exercise 1: Testing python
#
# Let's make a few test of the jupyter Notebook, first we use a generic function to print and press *Ctr+Enter*

# %%
print("Hello there!")
# Out:
# Hello there!

# %% [markdown]
# If we want to run the chunk and inter automatically another chunk we use *Shift+Enter*

# %%
print("General kenoby") #with shift+enter we insert another line
# Out:
# General kenoby

# %% [markdown]
# # Exercise 2
#
# Now that we have installed `numpy` we can activate the library with the name **np** and then use the function `arange` from the library

# %%
#import the library
import numpy as np 

#code to access the function arange from this library
print(np.arange(start=1, stop=10, step=3))
# Out:
# [1 4 7]

# %% [markdown]
# To use the function without calling the library we can import it directly

# %% [raw]
# #this cell is marked as 'raw' on the notebook so it won't run
# from numpy import arrange
# arange(start=1, stop=100, step=4)

# %% [markdown]
# To retrieve all 6the function inside a library we can go to the documentation or run the `dir` function

# %%
dir(np)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %% [markdown]
# we can also run terminal commands using ! , in this case to install `matplotlib`

# %%
# !pip install matplotlib

# %%
#activate the library
import matplotlib

# %%
#check the installation
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.1.0
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2026.1.4
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fonttools                 4.61.1
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# ...
