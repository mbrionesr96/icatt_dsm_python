# %% [markdown]
# # Exercise for variable definition and types

# %%
maxdistance=4
temperature=18.3
greet_ing="Alex"
isRainins=False

#1st_value -> value1
#Total$Amount -> total_amount
#calNum -> cal_num
#Data-Entry -> data_entry

#Convert and print 
int_a=45
flo_a=float(int_a)
type(flo_a)
# Out:
# float

# %%
pi=3.14159
int_pi=int(pi)

type(int_pi)
# Out:
# int

# %%
ex_float=99.99
ex_str=str(ex_float)

type(ex_str)
# Out:
# str

# %%
ex2_float=float(ex_str)

type(ex2_float)
# Out:
# float

# %% [markdown]
# # Exercise for operators

# %% [markdown]
# # Exercise using and manipulating Strings

# %%
#definition of strings
s1= 'Lord of the Rings is an excellent movie' 
s2= "Yes but Maria's favourite are the Star War's saga"
s3= """Which one? 
    the original tryology
    the precuel tryology 
    or the disney ones? """
print(s3)
# Out:
# Which one?
#     the original tryology
#     the precuel tryology
#     or the disney ones?

# %%
#concatenation 
print(s1 + ". " + s2)
# Out:
# Lord of the Rings is and excellent movie. Yes but Maria's favourite are thw Star War's saga

# %%
#Old Style to include 15 space characters and then extract the first 4 characters of s1
print("%15.4s" % s1)
# Out:
#            Lord

# %%
#str.format()
name="Maria"
print("Hello, I'm {0}".format(name))
# Out:
# Hello, I'm Maria

# %%
#f-string 
s4 = "My name is {fname}, I'm {age}".format(fname = "Maria", age = 29)
s4
# Out:
# "My name is Maria, I'm 29"

# %%
s5=s2[s2.find("Star"):42]+"s"+s1[-22:24]+(s1[-15:].upper())
s5
# Out:
# 'Star Wars is an EXCELLENT MOVIE'
